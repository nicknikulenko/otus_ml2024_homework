# %%
class BaseFileClass:
    def __init__(self, path, **kwargs):
        self.path = path
        self.__dict__.update(kwargs)

    def showConsole():
        pass

class ImageFileClass(BaseFileClass):
    def __init__(self, path, extension):
        super.__init__(self, path)
        self.extension = extension

    def convertTo(extToSave):
        pass

class OfficeFileClass(BaseFileClass):
    def __init__(self, path, extension, **kwargs):
        super.__init__(self, path, **kwargs)
        self.extension = extension

class TextFileClass(BaseFileClass):
    def __init__(self, path, extension, **kwargs):
        super.__init__(self, path, **kwargs)
        self.extension = extension

    def convertTo(extToSave):
        pass

    def showASCIIConsole():
        pass

class JPEGFileClass(ImageFileClass):
    def __init__(self, path, extension, **kwargs):
        super.__init__(self, path, extension, **kwargs)

class PNGFileClass(ImageFileClass):
    def __init__(self, path, extension, **kwargs):
        super.__init__(self, path, extension, **kwargs)

class WordFileClass(OfficeFileClass):
    def __init__(self, path, extension, version, **kwargs):
        super.__init__(self, path, extension, **kwargs)
        self.version = version


class ExcelFileClass(OfficeileClass):
    def __init__(self, path, extension, version, **kwargs):
        super.__init__(self, path, extension, **kwargs)
        self.version = version

class TxtFileClass(TextFileClass):
    def __init__(self, path, extension, **kwargs):
        super.__init__(self, path, extension, **kwargs)

class CsvFileClass(TextFileClass):
    def __init__(self, path, extension, **kwargs):
        super.__init__(self, path, extension, **kwargs)
